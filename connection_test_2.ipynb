# %%
import sys
import spotipy
import spotipy.util as util
import os
from dotenv import load_dotenv
import pprint

# %%
load_dotenv()

client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')
redirect_uri = 'http://localhost:9090/'

scope = ['user-read-recently-played']

token = util.prompt_for_user_token(scope = scope
                           , client_id = client_id
                           , client_secret = client_secret,
                           redirect_uri=redirect_uri)

# %%
res = sp.current_user_recently_played(limit=50, after=None, before=None)

# %%
pprint.pprint(res)
# Out:
# {'cursors': {'after': '1708034488229', 'before': '1707786517547'},
#  'href': 'https://api.spotify.com/v1/me/player/recently-played?limit=50',
#  'items': [{'context': None,
#             'played_at': '2024-02-15T22:01:28.229Z',
#             'track': {'album': {'album_type': 'compilation',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2x9SpqnPi8rlE9pjHBwmSC'},
#                                              'href': 'https://api.spotify.com/v1/artists/2x9SpqnPi8rlE9pjHBwmSC',
#                                              'id': '2x9SpqnPi8rlE9pjHBwmSC',
#                                              'name': 'Talking Heads',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2x9SpqnPi8rlE9pjHBwmSC'}],
#                                 'available_markets': ['AR',
#                                                       'AU',
# ...

# %%
### snippet to get the code

for item in res['items']:
    for artist in item['track']['artists']:
        print(artist['name'])
    break
# Out:
# Talking Heads

# %%
sp.track('2UeYOPHXD3sNdMuuElx8el')
# Out:
# {'album': {'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2x9SpqnPi8rlE9pjHBwmSC'},
#     'href': 'https://api.spotify.com/v1/artists/2x9SpqnPi8rlE9pjHBwmSC',
#     'id': '2x9SpqnPi8rlE9pjHBwmSC',
#     'name': 'Talking Heads',
#     'type': 'artist',
#     'uri': 'spotify:artist:2x9SpqnPi8rlE9pjHBwmSC'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
# ...

# %%
#Getting information about genre
artist_info = sp.artists(['2x9SpqnPi8rlE9pjHBwmSC'])
artist_info
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2x9SpqnPi8rlE9pjHBwmSC'},
#    'followers': {'href': None, 'total': 2345370.0},
#    'genres': ['alternative rock',
#     'art punk',
#     'dance rock',
#     'funk rock',
#     'new wave',
#     'permanent wave',
#     'post-punk',
#     'rock',
#     'zolo'],
#    'href': 'https://api.spotify.com/v1/artists/2x9SpqnPi8rlE9pjHBwmSC',
#    'id': '2x9SpqnPi8rlE9pjHBwmSC',
#    'images': [{'url': 'https://i.scdn.co/image/e4c5b04fce8706c87663357b1f78522a3a5c641b',
#      'height': 500.0,
#      'width': 500.0},
#     {'url': 'https://i.scdn.co/image/60bfd4ad01d8d9142d88c3c0b73cea36bf327ea7',
#      'height': 200.0,
#      'width': 200.0},
#     {'url': 'https://i.scdn.co/image/4056b1eaa81255de0865ebe4fdbe61246205153c',
#      'height': 64.0,
#      'width': 64.0}],
#    'name': 'Talking Heads',
#    'popularity': 68.0,
#    'type': 'artist',
#    'uri': 'spotify:artist:2x9SpqnPi8rlE9pjHBwmSC'}]}

# %%
audio_features = sp.audio_features(['2UeYOPHXD3sNdMuuElx8el'])
audio_features
# Out:
# [{'danceability': 0.612,
#   'energy': 0.418,
#   'key': 2,
#   'loudness': -14.431,
#   'mode': 1,
#   'speechiness': 0.0248,
#   'acousticness': 0.0422,
#   'instrumentalness': 0.0183,
#   'liveness': 0.133,
#   'valence': 0.639,
#   'tempo': 96.609,
#   'type': 'audio_features',
#   'id': '2UeYOPHXD3sNdMuuElx8el',
#   'uri': 'spotify:track:2UeYOPHXD3sNdMuuElx8el',
#   'track_href': 'https://api.spotify.com/v1/tracks/2UeYOPHXD3sNdMuuElx8el',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2UeYOPHXD3sNdMuuElx8el',
#   'duration_ms': 309267,
#   'time_signature': 4}]

# %%
from spotipy.oauth2 import SpotifyOAuth
import os
from spotipy import Spotify

load_dotenv()

client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')
redirect_uri = 'http://localhost:9090/'
scope = 'user-read-recently-played'

# Create the SpotifyOAuth object
auth_manager = SpotifyOAuth(client_id=client_id,
                            client_secret=client_secret,
                            redirect_uri=redirect_uri,
                            scope=scope)

# Create the Spotify client with the auth_manager
sp = Spotify(auth_manager=auth_manager)

# Now you can make calls to Spotify's API using sp
# For example, to get the recently played tracks:
results = sp.current_user_recently_played()
print(results)
# Out:
# {'items': [{'track': {'album': {'album_type': 'compilation', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2x9SpqnPi8rlE9pjHBwmSC'}, 'href': 'https://api.spotify.com/v1/artists/2x9SpqnPi8rlE9pjHBwmSC', 'id': '2x9SpqnPi8rlE9pjHBwmSC', 'name': 'Talking Heads', 'type': 'artist', 'uri': 'spotify:artist:2x9SpqnPi8rlE9pjHBwmSC'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'B
# ...
